# %%
from utils.utils import make_dataset
from utils.plotting import plot_random_samples, plot_single_sample, plot_counter, plot_brats_classes

# %%
data_path = make_dataset(dataset='glioma')
# Out:
# > > > > > > > > > > > > > > > > > > > > > > > > > > > > > > > > > > > > > > > >
#
# WARNING:  glioma directory not empty.
#
# DATA_PATH:  glioma/ASNR-MICCAI-BraTS2023-GLI-Challenge-TrainingData
#
# > > > > > > > > > > > > > > > > > > > > > > > > > > > > > > > > > > > > > > > >

# %%
plot_counter(data_path)

# %%
sample = 'BraTS-GLI-00019-000'
plot_single_sample(data_path, session=sample)
# Out:
# 'BraTS-GLI-00019-000'

# %%
plot_brats_classes(data_path, session=sample)
# Out:
# Image shape: (240, 240, 155)

# %%
plot_random_samples(folder=data_path, n_samples=4, axis=2)
