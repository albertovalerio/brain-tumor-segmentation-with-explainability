# %%
from utils.utils import make_dataset
from utils.plotting import plot_random_samples, plot_single_sample

# %%
train_path, eval_path = make_dataset(dataset='glioma')
# Out:
# > > > > > > > > > > > > > > > > > > > > > > > > > > > > > >
#
# WARNING:  glioma directory not empty.
#
# TRAIN_PATH:  glioma/ASNR-MICCAI-BraTS2023-GLI-Challenge-TrainingData
# EVAL_PATH:  glioma/ASNR-MICCAI-BraTS2023-GLI-Challenge-ValidationData
#
# > > > > > > > > > > > > > > > > > > > > > > > > > > > > > >

# %%
plot_single_sample(train_path)

# %%
plot_random_samples(folder=train_path, n_samples=4, axis=2)
